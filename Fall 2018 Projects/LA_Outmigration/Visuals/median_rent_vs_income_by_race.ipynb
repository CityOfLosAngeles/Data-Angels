# %% [markdown]
# # Plotting Race Characteristics using PERWT (Person Weight) from 2006 to 2017
# PERWT indicates how many persons in the US population are represented by a given person in an IPUMS sample.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/ipums_clean.csv")
df.count()
# Out:
# AGE            38158
# EDUC           38158
# EDUC_DESC      38158
# EMPSTAT        38158
# FTOTINC        38158
# INCTOT         38158
# IND            37838
# IND_CAT        37803
# MARST          38158
# MET2013        38158
# MORTAMT1       38158
# OCC2010        38158
# OCC2010_CAT    37265
# OWNERSHPD      38158
# PERWT          38158
# POVERTY        38158
# PUMA           38158
# RACE           38158
# RENT           38158
# SEX            38158
# YEAR           38158
# dtype: int64

# %%
df = df[['YEAR', 'RACE', 'PERWT', 'FTOTINC', 'INCTOT', 'MARST', 'OWNERSHPD', 'RENT']]
df.count()
# Out:
# YEAR         38158
# RACE         38158
# PERWT        38158
# FTOTINC      38158
# INCTOT       38158
# MARST        38158
# OWNERSHPD    38158
# RENT         38158
# dtype: int64

# %%
out_indiv = df[(df.INCTOT != 9999999) & (df.INCTOT <= df.FTOTINC)]
out_indiv = out_indiv[out_indiv.RENT != 0]
out_indiv.count()
# Out:
# YEAR         13327
# RACE         13327
# PERWT        13327
# FTOTINC      13327
# INCTOT       13327
# MARST        13327
# OWNERSHPD    13327
# RENT         13327
# dtype: int64

# %%
out_indiv.OWNERSHPD.value_counts()
# Out:
# With cash rent    13327
# dtype: int64

# %%
out_indiv.MARST.value_counts()
# Out:
# Never married/single       6470
# Married, spouse present    4367
# Divorced                   1318
# Married, spouse absent      441
# Separated                   386
# Widowed                     345
# dtype: int64

# %%
out_indiv = out_indiv.drop(['PERWT', 'FTOTINC', 'MARST', 'OWNERSHPD'], axis=1)
out_indiv
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13327 entries, 0 to 38156
# Data columns (total 4 columns):
# YEAR      13327  non-null values
# RACE      13327  non-null values
# INCTOT    13327  non-null values
# RENT      13327  non-null values
# dtypes: int64(3), object(1)

# %%
out_indiv.RENT.median()
# Out:
# 1100.0

# %%
out_indiv.INCTOT.median()
# Out:
# 18000.0

# %%
out_indiv.INCTOT = out_indiv.INCTOT/12.0
out_indiv.INCTOT.median()
# Out:
# 1500.0

# %%
# for each year, aggregate PERWT per race

year_race = out_indiv.groupby(['YEAR', 'RACE']).agg({'RENT':'median', 'INCTOT':'median'}).rename(
    columns={'RENT':'MEDIAN RENT', 'INCTOT':'MEDIAN MONTHLY INCOME'}
    )       
year_race.head()
# Out:
#                        MEDIAN RENT  MEDIAN MONTHLY INCOME
# YEAR RACE
# 2006 African American          870             892.500000
#      Asian                    1100            1250.000000
#      Hispanic                  850             958.333333
#      Mixed                    1200            1625.000000
#      Other                    1100             916.666667

# %%
# 2010 African American                         98.810613
#      Asian                                    87.272727
#      Hispanic                                 97.297297
#      Mixed                                    61.463415
#      Other                                    34.233687
#      White                                    65.454545
# 2011 African American                         84.480000
#      Asian                                   106.666667
#      Hispanic                                116.326531
#      Mixed                                    90.810811
#      Other                                   180.882353
#      White                                    61.146497
# 2012 African American                         82.000000
#      Asian                                    85.714286
#      Hispanic                                105.000000
#      Mixed                                   124.528302
#      Other                                    41.000000
#      White                                    57.600000
# 2013 African American                         97.864078
#      Asian                                    82.105263
#      Hispanic                                 78.523490
#      Mixed                                    80.487805
#      Other                                   180.000000
#      White                                    71.889401
# 2014 African American                         76.056338
#      Asian                                    83.333333
#      Hispanic                                107.889908
#      Mixed                                    53.215078
#      Other                                    88.846154
#      White                                    70.588235
# 2015 African American                         85.333333
#      Asian                                    84.000000
#      Hispanic                                106.024096
#      Mixed                                    96.594427
#      Other                                    54.098361
#      White                                    62.222222

# %%
year_race_rent = year_race['MEDIAN RENT AS PERCENT OF INCOME'].unstack()
year_race_rent.head(50)
# Out:
# RACE  African American       Asian    Hispanic       Mixed       Other      White
# YEAR
# 2006         97.478992   88.000000   88.695652   73.846154  120.000000  56.896552
# 2007        107.142857   65.753425   68.000000   52.000000  158.333333  52.718287
# 2008        105.283019   78.000000   85.714286  144.000000   45.846154  51.428571
# 2009         90.937500   93.023256   95.000000  300.000000  130.120482  60.000000
# 2010         98.810613   87.272727   97.297297   61.463415   34.233687  65.454545
# 2011         84.480000  106.666667  116.326531   90.810811  180.882353  61.146497
# 2012         82.000000   85.714286  105.000000  124.528302   41.000000  57.600000
# 2013         97.864078   82.105263   78.523490   80.487805  180.000000  71.889401
# 2014         76.056338   83.333333  107.889908   53.215078   88.846154  70.588235
# 2015         85.333333   84.000000  106.024096   96.594427   54.098361  62.222222
# 2016         92.307692   69.135802   78.571429   51.355207  226.086957  73.362445
# 2017         66.000000   97.142857   77.837838  131.645570   16.285714  60.504202

# %%
# Plotting Percent vs Year 

# %matplotlib inline
import matplotlib.pyplot as plt

ax = year_race_rent.plot(figsize=(25, 15), legend=True, fontsize=25, linewidth=6)
ax.set_title("Median Rent as % of Median Income (Single Income) By Race (%)\n", fontsize= 35)
ax.set_xlabel("\nYear", fontsize=0)
# ax.set_ylabel("Percentage (%)\n", fontsize=30)
ax.tick_params(axis = 'both', which = 'major', labelsize = 25)

leg = ax.legend(loc='best', prop={'size': 30});

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(30.0)
    
plt.xlim(left=2005)
plt.ylim(top=400, bottom=0)
plt.show()

# Save to file
fig = ax.get_figure()
fig.savefig("LA_Out-Migration_median_rent_percentage_income_by_race.jpg", bbox_inches='tight')
