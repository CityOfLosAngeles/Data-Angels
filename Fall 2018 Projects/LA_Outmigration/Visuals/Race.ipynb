# %% [markdown]
# # Plotting Race Characteristics using PERWT (Person Weight) from 2006 to 2017
# PERWT indicates how many persons in the US population are represented by a given person in an IPUMS sample.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/ipums_clean.csv")
la = pd.read_csv("../data/ipums_la_residents.csv")

# %%
df = df[['YEAR', 'RACE', 'PERWT']]

# %%
# for each year, aggregate PERWT per race

year_outmigrate_sum = df.groupby(['YEAR', 'RACE']).agg({'PERWT': 'sum'}).rename(
    columns={'PERWT':'OUT_MIGRATE'}
    )                                                                                  

year_residents_sum = la.groupby(['YEAR', 'RACE']).agg({'PERWT': 'sum'}).rename(
    columns={'PERWT':'RESIDENTS'}
    )

# %%
combined = pd.concat([year_outmigrate_sum, year_residents_sum], axis=1)

# add the number of out-migrated to residents to give total number of people originally reside in LA
combined['RESIDENTS'] = combined['RESIDENTS'] + combined['OUT_MIGRATE']

# %%
combined['PERCENT'] = 100.0 * combined['OUT_MIGRATE']/combined['RESIDENTS']
combined.head(36)
# Out:
#                        OUT_MIGRATE  RESIDENTS   PERCENT
# YEAR RACE
# 2006 African American        46993     962222  4.883800
#      Asian                   52029    1835474  2.834636
#      Hispanic               198111    5896944  3.359554
#      Mixed                    8924     191178  4.667901
#      Other                    3321      92270  3.599220
#      White                  170546    4452030  3.830747
# 2007 African American        44412     942477  4.712264
#      Asian                   39954    1829709  2.183626
#      Hispanic               165490    5834749  2.836283
#      Mixed                    6532     210540  3.102498
#      Other                    6439      81730  7.878380
#      White                  164019    4403766  3.724517
# 2008 African American        32648     925095  3.529151
#      Asian                   37520    1817304  2.064597
#      Hispanic               108898    5819349  1.871309
#      Mixed                    7856     221090  3.553304
#      Other                    1498      69448  2.157010
#      White                  140410    4346777  3.230209
# 2009 African American        29677     892245  3.326104
#      Asian                   33097    1838227  1.800485
#      Hispanic               122555    5885292  2.082395
#      Mixed                    7900     233591  3.381980
#      Other                    1814      66740  2.718010
#      White                  143274    4296749  3.334475
# 2010 African American        37445     891133  4.201954
#      Asian                   42054    1957140  2.148748
#      Hispanic               121541    5845140  2.079351
#      Mixed                    8214     269350  3.049564
#      Other                    2543      50312  5.054460
#      White                  137402    4183880  3.284081
# 2011 African American        27776     881012  3.152738
#      Asian                   31454    1969617  1.596960
#      Hispanic               112286    5916154  1.897956
#      Mixed                    9630     271772  3.543411
#      Other                    2154      48329  4.456951
#      White                  137584    4180942  3.290742

# %%
combined.tail(36)
# Out:
#                        OUT_MIGRATE  RESIDENTS   PERCENT
# YEAR RACE
# 2012 African American        20047     859900  2.331318
#      Asian                   42190    1998202  2.111398
#      Hispanic               108013    5965742  1.810554
#      Mixed                    9133     324142  2.817592
#      Other                     984      60334  1.630921
#      White                  116460    4139238  2.813561
# 2013 African American        29741     882231  3.371113
#      Asian                   45010    2046613  2.199243
#      Hispanic               104690    6005995  1.743092
#      Mixed                   12581     310507  4.051761
#      Other                    1585      51514  3.076833
#      White                  129307    4157695  3.110065
# 2014 African American        32979     878715  3.753094
#      Asian                   44838    2098282  2.136891
#      Hispanic               109932    6088905  1.805448
#      Mixed                   12074     331195  3.645586
#      Other                    2241      59132  3.789826
#      White                  153456    4161448  3.687563
# 2015 African American        32448     894275  3.628414
#      Asian                   50194    2144661  2.340417
#      Hispanic               110678    6126680  1.806492
#      Mixed                   11432     325730  3.509655
#      Other                    1882      61548  3.057776
#      White                  147772    4143656  3.566223
# 2016 African American        28002     869332  3.221094
#      Asian                   55734    2170831  2.567404
#      Hispanic               122288    6129433  1.995095
#      Mixed                   14933     332412  4.492317
#      Other                    3166      67690  4.677205
#      White                  144388    4111506  3.511803
# 2017 African American        31081     874590  3.553779
#      Asian                   48170    2195258  2.194275
#      Hispanic               124613    6155729  2.024342
#      Mixed                   13536     352341  3.841733
#      Other                    1788      66714  2.680097
#      White                  143594    4070102  3.528020

# %%
combined = combined['PERCENT'].unstack()
combined.head()
# Out:
# RACE  African American     Asian  Hispanic     Mixed    Other     White
# YEAR
# 2006          4.883800  2.834636  3.359554  4.667901  3.59922  3.830747
# 2007          4.712264  2.183626  2.836283  3.102498  7.87838  3.724517
# 2008          3.529151  2.064597  1.871309  3.553304  2.15701  3.230209
# 2009          3.326104  1.800485  2.082395  3.381980  2.71801  3.334475
# 2010          4.201954  2.148748  2.079351  3.049564  5.05446  3.284081

# %%
# Plotting Percent vs Year 

# %matplotlib inline
import matplotlib.pyplot as plt

ax = combined.plot(figsize=(30, 15), legend=True, fontsize=25, linewidth=3)
ax.set_title("LA Out-Migration by Race", fontsize= 25)
ax.set_xlabel("Year", fontsize=25)
ax.set_ylabel("Percentage", fontsize=25)
ax.tick_params(axis = 'both', which = 'major', labelsize = 20)

leg = ax.legend(loc='best', prop={'size': 25});

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(20.0)
    
plt.show()

# Save to file
fig = ax.get_figure()
fig.savefig("LA_Out-Migration_by_race.jpg")
